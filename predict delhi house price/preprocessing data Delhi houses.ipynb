# %%
import pandas as pd

# %%
raw = pd.read_csv('Delhi_v2.csv')
raw
# Out:
#       index     price                                            Address  \
# 0         0   5600000                  Noida Extension, Noida, Delhi NCR
# 1         1   8800000                      Sector 79, Gurgaon, Delhi NCR
# 2         2  16500000                     Vaishali, Ghaziabad, Delhi NCR
# 3         3   3810000  Link Road, F Block, Sector 50, Noida, Uttar Pr...
# 4         4   6200000  Jaypee Pavilion Court Sector 128, Noida, Secto...
# ...     ...       ...                                                ...
# 7733   7733   7900000                  Indirapuram, Ghaziabad, Delhi NCR
# 7734   7734   4510000  Greater Noida, Sector 2, Greater Noida, Delhi NCR
# 7735   7735   7000000           Crossings Republik, Ghaziabad, Delhi NCR
# 7736   7736   6500000  Raj Nagar Extension, Ghaziabad, Raj Nagar Exte...
# 7737   7737   6500000  sandal apartment, Shalimar Garden Extension 1,...
#
#       area   latitude  longitude  Bedrooms  Bathrooms  Balcony  \
# ...

# %%
raw.isnull().sum()
# Out:
# index                  0
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony             2572
# Status               574
# neworold               0
# parking             5126
# Furnished_status    3614
# Lift                6005
# Landmarks           4979
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %%
data = raw.copy()

# %%
data.dropna(subset=['Status'], inplace=True)
# data.dropna(subset=['Landmarks'], inplace=True)
# data.dropna(subset=['Furnished_status'], inplace=True)

# %%
data.isnull().sum()
# Out:
# index                  0
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony             2318
# Status                 0
# neworold               0
# parking             4724
# Furnished_status    3608
# Lift                5519
# Landmarks           4537
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %%
want_to_drop = ['Landmarks','Furnished_status','desc']
data_1 = data.drop(want_to_drop, axis=1)

# %%
data_1.reset_index()
# Out:
#       level_0  index     price  \
# 0           0      0   5600000
# 1           1      1   8800000
# 2           2      2  16500000
# 3           4      4   6200000
# 4           5      5   3700000
# ...       ...    ...       ...
# 7159     7732   7732   6200000
# 7160     7733   7733   7900000
# 7161     7735   7735   7000000
# 7162     7736   7736   6500000
# 7163     7737   7737   6500000
#
#                                                 Address  area   latitude  \
# 0                     Noida Extension, Noida, Delhi NCR  1350  28.608850
# 1                         Sector 79, Gurgaon, Delhi NCR  1490  28.374236
# 2                        Vaishali, Ghaziabad, Delhi NCR  2385  28.645769
# 3     Jaypee Pavilion Court Sector 128, Noida, Secto...  1350  28.520732
# 4     tower 2, 6th floor, Crossings Republik, Ghazia...  1150  28.628040
# ...                                                 ...   ...        ...
# ...

# %%
data_1.fillna(0, inplace=True)
data_1
# Out:
#       index     price                                            Address  \
# 0         0   5600000                  Noida Extension, Noida, Delhi NCR
# 1         1   8800000                      Sector 79, Gurgaon, Delhi NCR
# 2         2  16500000                     Vaishali, Ghaziabad, Delhi NCR
# 4         4   6200000  Jaypee Pavilion Court Sector 128, Noida, Secto...
# 5         5   3700000  tower 2, 6th floor, Crossings Republik, Ghazia...
# ...     ...       ...                                                ...
# 7732   7732   6200000  Sector137 Noida Paramount Floraville, Sector 1...
# 7733   7733   7900000                  Indirapuram, Ghaziabad, Delhi NCR
# 7735   7735   7000000           Crossings Republik, Ghaziabad, Delhi NCR
# 7736   7736   6500000  Raj Nagar Extension, Ghaziabad, Raj Nagar Exte...
# 7737   7737   6500000  sandal apartment, Shalimar Garden Extension 1,...
#
#       area   latitude  longitude  Bedrooms  Bathrooms  Balcony  \
# ...

# %%
data_1.to_csv('Delhi houses_2', index=False)
